# %%
#Reading the tamil characters from the text file
import os
from pathlib import Path

data_path = "dataset/tamil_pretrain.txt"


def chunk_filereader(fp, block_size:int = 8192):
    while True:
        data_chunk = fp.read(block_size)
        if not data_chunk:
            break
        yield data_chunk


def read_file_main(filepath: str, encoding_type: str):
    print(f"Reading the file: {filepath}")
    print(f"Size of the file: {os.path.getsize(filepath)}")
    print("**********************************************")
    print()
    with open(filepath, "r", encoding=encoding_type) as data_file:
        for chunk in chunk_filereader(data_file):
            print(chunk)

# %%
read_file_main(filepath=data_path, encoding_type="utf-8")
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ு?’ என்று கவலைப் பட்டார் ரங்கநாதன்.
#
# 36. இன்டர்வியூ செய்பவர்களை எப்படி அழைப்பது என்பதே பெரிய சிக்கலாக பலருக்குத் தெரியும். இந்தியர் களை 'சார்' என்று அழைக்கலாம். 'என் முதல் பெயரால் கூப்பிடு' என்று சொல்லும் அமெரிக்கரை, அவர் சொன்னபடியே அழைக்கலாம். மரியாதை கூடுதலாக இருந்தாலும் பரவாயில்லை... குறையக் கூடாது.
#
# புதுச்சேரி-புதுச்சேரி சட்டசபை தேர்தலையொட்டி, அனைத்து பள்ளிகளுக்கும் நாளை 2ம் தேதி முதல், 7ம் தேதி வரை விடுமுறை அளிக்கப்பட்டுள்ளது.இது குறித்து புதுச்சேரி பள்ளி கல்வித் துறை இணை இயக்குனர் மைக்கேல் பென்னோ வெளியிட்டுள்ள செய்திக்குறிப்புபுதுச்சேரி சட்டசபை தேர்தல், வரும் 6ம் தேதி நடைபெற உள்ளது. அதையொட்டி புதுச்சேரி மாநிலத்தில் உள்ள அனைத்து பள்ளிகளுக்கும் நாளை 2ம் தேதி முதல் 7ம் தேதி வரை விடுமுறை அளிக்கப்படுகிறது. பத்தாம் வகுப்பு மற்றும் பிளஸ் 2 வகுப்புகளுக்கு 8ம் தேதி முதல் வகுப்புகள் நடைபெறும்.இவ்வாறு அதில் கூறப்பட்டுள்ளது.மாணவர், பெற்றோர் குழப்பம்கொரோனா தொற்று அதிகரித்து வரும் சூழ்நிலையில், புதுச்சேரியில் தமிழக பாடத்திட்டத்தின் கீழ் செயல்படும் பள்ளிகள், 1ம் வகுப்பு முதல் பிளஸ் 1 வகுப்பு வரை ரெகுலர் அல்லது சிறப்பு வகுப்பு நடத்தக் கூடாது. பொதுத்தேர்வு காரணமாக பிளஸ் 2 மாணவர்களுக்கு மட்டும் வகுப்பு நடத்தலாம் என பள்ளி கல்வித் துறை உத்தரவிட்டது.மேலும், சி.பி.எஸ்.இ., - ஐ.சி.எஸ்.இ., பாடத்திட்டத்தின் கீழ் செயல்படும் பள்ளிகள் 1ம் வகுப்பு முதல் 9ம் வகுப்பு வரை மற்றும் பிளஸ் 1 மாணவர்களுக்கு ரெகுலர், சிறப்பு வகுப்பு நடத்த கூடாது. 10 மற்றும் பிளஸ் 2 வகுப்புகளுக்கு பொதுத்தேர்வு வர உள்ளதால், வகுப்புகள் நடத்தி கொள்ளலாம் என அறிவித்தது.பள்ளிக்குவர வேண்டியது சி.பி.எஸ்.இ., மாணவர்களா, மாநில பாட வாரிய பள்ளி மாணவர்களா என்பதை குறிப்பிடாததால் பெற்றோர் மற்றும் மாணவர்கள் குழப்பம் அடைந்துள்ளனர்.
்ளீர்கள். இதைத் தக்க வைத்துக் கொள்ள நிச்சயம் முயல்வேன். தெம்பூட்டி கருத்துக்கு என் மனம் நிறைந்த நன்றி ஸார். வலைச்சரத்தில் கலக்கல் அறிமுகம் கணேஸ் அண்ணா . இத்தனை பேரையும் உடனே படிக்க முடியாவிட்டாலும் சேர்த்துவைத்துப் படிக்கின்றேன் பின். ஆரம்பமே அசத்தலாக இருக்கிறது. இந்த வாரமே அசத்தலாக இருக்கும் என்பதில் எந்த வித சந்தேகமும் இல்லை. உங்கள் பழைய பதிவுகளை பொறுமையாக படிக்க வேண்டும்.... எனக்கு முதல் அங்கீகாரம் தந்த உங்களின் வாழ்த்துககளில் அகமகிழ்ந்த என் உளம்கனிந்த நன்றியை உரித்தாக்குகிறேன். நான் வலைசாரம் பக்கம் வருவது உங்களை போல உள்ள பதிவாளர்கள் வலைச்சாரத்தில் பதிவு இடும் போதுதான். அதனால்தான் நான் கடைசியாக வந்து வாழ்த்து சொல்கிறேன். உங்களை போல நல்ல வாத்தியார் வரும் போது வகுப்புக்கு மட்டம் போடாமல் வந்துவிடுவேன் .உங்களுக்கு எனது மனமார்ந்த வாழ்த்துக்கள் டியர் ஃப்ரெண்ட்! வகுப்புகளுககு மட்டம் போடாமல் வந்துவிடுவேன் என்று நீங்கள் சொன்னதைவிட மகிழ்வான வார்த்தை வேறென்ன எனக்கு? உங்களுக்கு என் இதயம் நிறை நன்றி! கோமாளியோட எழுத்து போல தெரியலியே அண்ணா. சுதம்பட்டம் நல்லாவே இருக்கு. உங்க அறிமுகத்துல நானும் உண்டுதானே வாழ்த்துகள் கணேஷ். உங்கள் பதிவுகளில் நான் பார்க்காத சிலவற்றை எடுத்துக் காட்டியிருப்பதில் அவற்றைப் பார்த்து வந்தேன்! தொடர்ந்து கலக்குங்கள். கோடை மழை பொழியட்டும்! நீயெல்லாம் இல்லாமலாம்மா? எப்பன்றதை தெரிஞ்சுக்க வெயிட் ப்ளீஸ்!சுய தம்பட்டத்தையும் ரசிச்ச தங்கைக்கு என் இதய நன்றி! ரொம்ப நாளைக்கப்புறம் வந்தாலும் சரியான சமயத்துல வந்து என்னை வாழ்த்தினதுல மகிழ்ச்சி தோழி! நீங்க வலைச்சரம் ப்ரஸண்ட் பண்ணின ஸ்டைல்தான் எனக்கு இன்ஸ்பிரேஷனே! உஙகளு ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 read_file_main(filepath=data_path, encoding_type="utf-8")
#
# Cell In[4], line 22, in read_file_main(filepath, encoding_type)
#      20 print()
#      21 with open(filepath, "r", encoding=encoding_type) as data_file:
# ---> 22     for chunk in chunk_filereader(data_file):
#      23         print(chunk)
#
# Cell In[4], line 10, in chunk_filereader(fp, block_size)
#       8 def chunk_filereader(fp, block_size:int = 8192):
#       9     while True:
# ---> 10         data_chunk = fp.read(block_size)
#      11         if not data_chunk:
#      12             break
#
# File /usr/local/llm_pretrain/venv/lib/python3.10/codecs.py:319, in BufferedIncrementalDecoder.decode(self, input, final)
#     314 def _buffer_decode(self, input, errors, final):
#     315     # Overwrite this method in subclasses: It must decode input
#     316     # and return an (output, length consumed) tuple
#     317     raise NotImplementedError
# --> 319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
#     322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#
# KeyboardInterrupt:

# %%
sample_text = "இந்தியா சார்பாக கடந்த போட்டியில் விளையாடிய உமேஷ் யாதவ்வைப் பிரதியிட்ட நவ்தீப் சைனி"

# %%
utf_8_encodes = list(sample_text.encode("utf-8"))

# %%
utf16_encodes = list(sample_text.encode("utf-16"))

# %%
utf32_encodes = list(sample_text.encode("utf-32"))

# %%
print(len(utf_8_encodes), len(utf16_encodes), len(utf32_encodes))
# Out:
# 228 166 332

# %%
### Lets write the BPE Tokenizer from scratch
sample = sample_text
print("---")
print(sample)
print("---")
tokens = sample.encode("utf-8") # raw bytes
print(f"length of raw bytes: {len(tokens)}")
print(tokens)
print("---")
tokens = list(map(int, tokens)) # raw bytes converted to numbers
print(tokens)
print(f"length of raw bytes converted to numbers: {len(tokens)}")
# Out:
# ---
# இந்தியா சார்பாக கடந்த போட்டியில் விளையாடிய உமேஷ் யாதவ்வைப் பிரதியிட்ட நவ்தீப் சைனி
# ---
# length of raw bytes: 228
# b'\xe0\xae\x87\xe0\xae\xa8\xe0\xaf\x8d\xe0\xae\xa4\xe0\xae\xbf\xe0\xae\xaf\xe0\xae\xbe \xe0\xae\x9a\xe0\xae\xbe\xe0\xae\xb0\xe0\xaf\x8d\xe0\xae\xaa\xe0\xae\xbe\xe0\xae\x95 \xe0\xae\x95\xe0\xae\x9f\xe0\xae\xa8\xe0\xaf\x8d\xe0\xae\xa4 \xe0\xae\xaa\xe0\xaf\x8b\xe0\xae\x9f\xe0\xaf\x8d\xe0\xae\x9f\xe0\xae\xbf\xe0\xae\xaf\xe0\xae\xbf\xe0\xae\xb2\xe0\xaf\x8d \xe0\xae\xb5\xe0\xae\xbf\xe0\xae\xb3\xe0\xaf\x88\xe0\xae\xaf\xe0\xae\xbe\xe0\xae\x9f\xe0\xae\xbf\xe0\xae\xaf \xe0\xae\x89\xe0\xae\xae\xe0\xaf\x87\xe0\xae\xb7\xe0\xaf\x8d \xe0\xae\xaf\xe0\xae\xbe\xe0\xae\xa4\xe0\xae\xb5\xe0\xaf\x8d\xe0\xae\xb5\xe0\xaf\x88\xe0\xae\xaa\xe0\xaf\x8d \xe0\xae\xaa\xe0\xae\xbf\xe0\xae\xb0\xe0\xae\xa4\xe0\xae\xbf\xe0\xae\xaf\xe0\xae\xbf\xe0\xae\x9f\xe0\xaf\x8d\xe0\xae\x9f \xe0\xae\xa8\xe0\xae\xb5\xe0\xaf\x8d\xe0\xae\xa4\xe0\xaf\x80\xe0\xae\xaa\xe0\xaf\x8d \xe0\xae\x9a\xe0\xaf\x88\xe0\xae\xa9\xe0\xae\xbf'
# ---
# [224, 174, 135, 224, 174, 168, 224, 175, 141, 224, 174, 164, 224, 174, 191, 224, 174, 175, 224, 174, 190, 32, 224, 174, 154, 224, 174, 190, 224, 174, 176, 224, 175, 141, 224, 174, 170, 224, 174, 190, 224, 174, 149, 32, 224, 174, 149, 224, 174, 159, 224, 174, 168, 224, 175, 141, 224, 174, 164, 32, 224, 174, 170, 224, 175, 139, 224, 174, 159, 224, 175, 141, 224, 174, 159, 224, 174, 191, 224, 174, 175, 224, 174, 191, 224, 174, 178, 224, 175, 141, 32, 224, 174, 181, 224, 174, 191, 224, 174, 179, 224, 175, 136, 224, 174, 175, 224, 174, 190, 224, 174, 159, 224, 174, 191, 224, 174, 175, 32, 224, 174, 137, 224, 174, 174, 224, 175, 135, 224, 174, 183, 224, 175, 141, 32, 224, 174, 175, 224, 174, 190, 224, 174, 164, 224, 174, 181, 224, 175, 141, 224, 174, 181, 224, 175, 136, 224, 174, 170, 224, 175, 141, 32, 224, 174, 170, 224, 174, 191, 224, 174, 176, 224, 174, 164, 224, 174, 191, 224, 174, 175, 224, 174, 191, 224, 174, 159, 224, 175, 141, 224, 174, 159, 32, 224, 174, 168, 224, 174, 181, 224, 175, 141, 224, 174, 164, 224, 175, 128, 224, 174, 170, 224, 175, 141, 32, 224, 174, 154, 224, 175, 136, 224, 174, 169, 224, 174, 191]
# length of raw bytes converted to numbers: 228

# %%
def find_pairs_count(token_list: list):
    pair_dict = {}
    for i, ele in enumerate(token_list):
        if i < len(token_list)-1:
            pairs = (token_list[i], token_list[i+1])
            if pairs not in pair_dict:
                pair_dict[pairs] = 1
            else:
                pair_dict[pairs] += 1

    return pair_dict

# %%
pairwise_freq = find_pairs_count(tokens)

# %%
sorted_pairwise_freq = sorted(pairwise_freq, reverse=True, key= lambda item: item[1])

# %%
sorted_pairwise_freq
# Out:
# [(135, 224),
#  (168, 224),
#  (141, 224),
#  (164, 224),
#  (191, 224),
#  (175, 224),
#  (32, 224),
#  (154, 224),
#  (190, 224),
#  (176, 224),
#  (170, 224),
#  (149, 224),
#  (159, 224),
#  (139, 224),
#  (178, 224),
#  (181, 224),
#  (179, 224),
#  (136, 224),
#  (137, 224),
#  (174, 224),
#  (183, 224),
#  (128, 224),
#  (169, 224),
#  (174, 191),
#  (174, 190),
#  (174, 183),
#  (174, 181),
#  (174, 179),
#  (174, 178),
#  (174, 176),
#  (224, 175),
#  (174, 175),
#  (224, 174),
#  (174, 174),
#  (174, 170),
#  (174, 169),
#  (174, 168),
#  (174, 164),
#  (174, 159),
#  (174, 154),
#  (174, 149),
#  (175, 141),
#  (175, 139),
#  (174, 137),
#  (175, 136),
#  (174, 135),
#  (175, 135),
#  (175, 128),
#  (190, 32),
#  (149, 32),
#  (164, 32),
#  (141, 32),
#  (175, 32),
#  (159, 32)]
